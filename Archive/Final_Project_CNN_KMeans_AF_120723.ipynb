# %% [markdown]
# # Final Project
#
# ### <span style="color:gray"> Violet Davis and Annie Friar </span>

# %% [markdown]
# ###
# `Data Exploration`

# %% [markdown]
# ---

# %%
# Import libraries

# standard
import pandas as pd
import numpy as np
import random
import os

# tf and keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras import models
from keras import layers
from keras.regularizers import l2

# plots and images
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image

#silence TF
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

random.seed(2)
# %matplotlib inline

# FILL IN CODE HERE #
NORMAL_IMAGE_PATH = 'drive/MyDrive/207_final_project/Final_Project_Data/normal/' # Class as 1
GLIOMA_IMAGE_PATH = 'drive/MyDrive/207_final_project/Final_Project_Data/glioma_tumor/' # Class as 2
MENINGIOMA_IMAGE_PATH = 'drive/MyDrive/207_final_project/Final_Project_Data/meningioma_tumor/' # Class as 3
PITUITARY_IMAGE_PATH = 'drive/MyDrive/207_final_project/Final_Project_Data/pituitary_tumor/' # Class as 4

#import drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Dataset

# %%
# read image
indx=0
images = []
labels = []

labels_index = 0

print('Sample of normal images in data:')
for idx, img in enumerate(os.listdir(NORMAL_IMAGE_PATH)):
    img = load_img(
    NORMAL_IMAGE_PATH + img)
    images.append(img)
    labels.append((idx, 0))
    labels_index = idx

normal_index = labels_index + 1

for idx, img in enumerate(os.listdir(GLIOMA_IMAGE_PATH)):
    img = load_img(
    GLIOMA_IMAGE_PATH + img)
    images.append(img)
    labels.append((idx+normal_index, 1))
    labels_index = idx

glioma_index = normal_index + labels_index + 1

for idx, img in enumerate(os.listdir(MENINGIOMA_IMAGE_PATH)):
    img = load_img(
    MENINGIOMA_IMAGE_PATH + img)
    images.append(img)
    labels.append((idx+glioma_index, 2))
    labels_index = idx

meningioma_index = glioma_index + labels_index + 1

for idx, img in enumerate(os.listdir(PITUITARY_IMAGE_PATH)):
    img = load_img(
    PITUITARY_IMAGE_PATH + img)
    images.append(img)
    labels.append((idx+meningioma_index, 3))
# Out:
# Sample of normal images in data:

# %%
labels = np.array(labels)

# %%
labels_df = pd.DataFrame(labels,
                   columns=['img_num', 'Label'])

# %%
labels_df['Label'].value_counts()
# Out:
# 2    923
# 1    901
# 3    844
# 0    438
# Name: Label, dtype: int64

# %%
# histogram
sns.histplot(
    data=labels_df,
    stat="count",
    x = "Label"
);

# %% [markdown]
# ## Split Images Datasets

# %% [markdown]
# `Correct for data imbalance`

# %%
np.random.seed(1234)

n_size = 438

normal = labels_df[labels_df['Label'] == 0]
glioma = labels_df[labels_df['Label'] == 1]
meningioma = labels_df[labels_df['Label'] == 2]
pituitary = labels_df[labels_df['Label'] == 3]

# randomly draw 400 images from each classes
temp_normal = list(np.random.choice(
    normal.img_num,
    size=n_size,
    replace=False
))

temp_glioma = list(np.random.choice(
    glioma.img_num,
    size=n_size,
    replace=False
))

temp_meningioma = list(np.random.choice(
    meningioma.img_num,
    size=n_size,
    replace=False
))


temp_pituitary = list(np.random.choice(
    pituitary.img_num,
    size=n_size,
    replace=False
))

# %%
image_list = []
labels_list = []

for num in temp_normal:
    image_list.append(images[num])
    labels_list.append(labels[num])

for num in temp_glioma:
    image_list.append(images[num])
    labels_list.append(labels[num])

for num in temp_meningioma:
    image_list.append(images[num])
    labels_list.append(labels[num])

for num in temp_pituitary:
    image_list.append(images[num])
    labels_list.append(labels[num])

# %%
print("Length of Image List: ", len(image_list))
print("Length of Labels List: ", len(labels_list))
# Out:
# Length of Image List:  1752
# Length of Labels List:  1752

# %%
images_mini = []
y_mini = []

for img in image_list:

# transform image to array
    img = img_to_array(img)

    # append to images
    images_mini.append(img)

images_mini = np.stack(images_mini)

for label in labels_list:
    y_mini.append(label[1])

y_mini = np.array(y_mini)

# %%
images_mini.shape
# Out:
# (1752, 256, 256, 3)

# %%
y_mini.shape
# Out:
# (1752,)

# %% [markdown]
# ## Image Augmentation

# %%
tf.random.set_seed(1234)

fig = plt.figure(figsize=(14, 12))

# pull first image from data
image = images_mini[0]

# plot original
ax = fig.add_subplot(1, 5, 1)
ax.imshow(array_to_img(image))
ax.set_title('Original', size=15);

# flip left right
ax = fig.add_subplot(1, 5, 2)
img_flip = tf.image.flip_left_right(image)
ax.imshow(array_to_img(img_flip))
ax.set_title('Step 1: Flip left right', size=15);

# flip up down
ax = fig.add_subplot(1, 5, 3)
img_flip = tf.image.flip_up_down(image)
ax.imshow(array_to_img(img_flip))
ax.set_title('Step 2: Flip up down', size=15);

# rotate
#ax = fig.add_subplot(1, 5, 4)
#img_rotate = tf.image.rot90(image)
#ax.imshow(array_to_img(img_rotate))
#ax.set_title('Step 3: Rotate', size=15);

# %%
def preprocess_data_part2(images, y, split=(0.6,0.2,0.2)):
    """ Split data into train, validation and test sets

    Params:
    -------
    images  (np.ndarray): Images of shape (N, 256, 256, 1)
    y (np.ndarray): Labels of shape (N,)
    split (tuple): 3 values summing to 1 defining split of train, validation and test sets

    Returns:
    --------
    X_train (np.ndarray): Train images of shape (N_train, 256, 256, 1)
    y_train (np.ndarray): Train labels of shape (N_train,)
    X_val (np.ndarray): Val images of shape (N_val, 256, 256, 1)
    y_val (np.ndarray): Val labels of shape (N_val,)
    X_test (np.ndarray): Test images of shape (N_test, 256, 224, 1)
    y_test (np.ndarray): Test labels of shape (N_test,)

    """

    ### create train/validation/test sets ###
    #########################################
    # NOTE: Each time you run this cell, you'll re-shuffle the data. The ordering will be the same due to the random seed generator
    tf.random.set_seed(1234)
    np.random.seed(1234)

    shuffle = np.random.permutation(np.arange(len(images)))
    images, y = images[shuffle], y[shuffle]

    splits = np.multiply(len(images_mini), split).astype(int)
    X_train, X_val, X_test = np.split(images, [splits[0], splits[0]+splits[1]])
    y_train, y_val, y_test = np.split(y, [splits[0], splits[0]+splits[1]])

    # rescale image to [0,1]
    X_train = tf.image.rgb_to_grayscale(X_train)/255.0
    X_val = tf.image.rgb_to_grayscale(X_val)/255.0
    X_test = tf.image.rgb_to_grayscale(X_test)/255.0

    ### image augmentation on training data ###
    ###########################################

    # random flip
    X_train_augm = tf.image.random_flip_left_right(X_train)

    # random flip up
    X_train_augm = tf.image.random_flip_up_down(X_train_augm)

    # random rotate - not working
    #X_train_augm = tf.image.random_rotation(X_train_augm, 90)

    # concatenate original X_train and augmented X_train data
    X_train = tf.concat([X_train, X_train_augm],axis=0)

    # concatenate y_train (note the label is preserved)
    y_train_augm = y_train
    y_train = tf.concat([y_train, y_train_augm],axis=0)

    # shuffle X_train and y_train, i.e., shuffle two tensors in the same order
    shuffle = tf.random.shuffle(tf.range(tf.shape(X_train)[0], dtype=tf.int32))
    X_train = tf.gather(X_train, shuffle)
    y_train = tf.gather(y_train, shuffle).numpy() #also transforms y_train to numpy array

    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
X_train, y_train, X_val, y_val, X_test, y_test = preprocess_data_part2(
    images_mini,
    y_mini,
    split=(0.6,0.2,0.2)
)

print(f"X_train shape {X_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_val shape {X_val.shape}")
print(f"y_val shape {y_val.shape}")
print(f"X_test shape {X_test.shape}")
print(f"y_test shape {y_test.shape}")
# Out:
# X_train shape (2102, 256, 256, 1)
# y_train shape (2102,)
# X_val shape (350, 256, 256, 1)
# y_val shape (350,)
# X_test shape (351, 256, 256, 1)
# y_test shape (351,)

# %%
validate_split = pd.DataFrame(y_train)

# %%
validate_split.value_counts()
# Out:
# 0    542
# 3    528
# 2    518
# 1    514
# dtype: int64

# %%
y_train.shape
# Out:
# (2102,)

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
y_train_dense = np.copy(y_train)
y_val_dense = np.copy(y_val)
y_test_dense = np.copy(y_test)

# %%
type(y_train_dense)
# Out:
# numpy.ndarray

# %%
def get_one_hot_labels(dense_labels):

  one_hot_labels = []

  for label in dense_labels:
    if label == 0:
      one_hot_labels.append([1,0,0,0])
    elif label == 1:
      one_hot_labels.append([0,1,0,0])
    elif label == 2:
      one_hot_labels.append([0,0,1,0])
    elif label == 3:
      one_hot_labels.append([0,0,0,1])
    else:
      print(label)
      raise Exception

  one_hot_labels = np.array(one_hot_labels)

  return one_hot_labels

# %%
y_train = get_one_hot_labels(y_train)
y_val = get_one_hot_labels(y_val)
y_test = get_one_hot_labels(y_test)

# %%
y_train.shape
# Out:
# (2102, 4)

# %% [markdown]
# ##SVD

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
X_train_example = X_train[:1]

# %%
def svd_compressor(image, order):
    """Returns the compressed image channel at the specified order"""

    # Create an array filled with zeros having the shape of the image
    compressed = np.zeros(image.shape)

    # Get the U, S and V terms (S = SIGMA)
    U, S, V = np.linalg.svd(image)

    # Loop over U columns (Ui), S diagonal terms (Si) and V rows (Vi) until the chosen order
    for i in range(order):
        Ui = U[:, i].reshape(-1, 1)
        Vi = V[i, :].reshape(1, -1)
        Si = S[i]
        compressed += (Ui * Si * Vi)

    return compressed

# %%
for img in X_train_example:
  img = array_to_img(img)
  gray_image = img

# %%
# Convert to Numpy array for the function
gray_image = np.array(gray_image)

orders = [1, 5, 10, 20, 50, 100, 150, 256]
rmse = []

plt.figure(figsize=(25, 10))

for i in tqdm(range(len(orders))):

    # Use the compressor function
    order = orders[i]
    gray_comp = svd_compressor(gray_image, order)

    # Round the calculated values and convert them from float to int.
    gray_comp = np.around(gray_comp).astype(int)

    # Calculate RMSE
    rmse.append(np.sqrt(np.mean((gray_image - gray_comp)**2)))

    # Display the compressed gray image in the subplot
    plt.subplot(2, 4, i + 1)
    plt.title("Order = {} | RMSE = {:.2f}".format(order, rmse[i]))
    plt.axis('off')
    plt.imshow(gray_comp, cmap='gray')

plt.suptitle('Compression at different orders')
plt.show()
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 19.26it/s]

# %%
def f(x, a, b, c, d):
    return a * np.log(b * x + c) + d

x_fit = np.linspace(orders[0], orders[-1], 100)
params = curve_fit(f, orders, rmse, bounds=(0,40))
y_fit = f(x_fit, *params[0])

plt.figure(figsize=(10, 4))
plt.scatter(orders, rmse, label="compressed images")
#plt.plot(x_fit, y_fit, c='r', ls='-', label="fit")
plt.title("RMSE decreases as the compression order increases")
plt.xlabel("Compression Order")
plt.ylabel("RMSE")
plt.grid('on')
plt.legend()
plt.show()

# %%
def svd_compress_image_data(images_array):
  comp_images_array = []

  compress_to = 50

  for img in images_array:
    img = array_to_img(img)
    gray_image = img

    gray_image = np.array(gray_image)

    gray_comp = svd_compressor(gray_image, compress_to)

    # Round the calculated values and convert them from float to int.
    gray_comp = np.around(gray_comp).astype(int)

    comp_final = img_to_array(gray_comp)

    comp_images_array.append(comp_final)

  return comp_images_array

# %%
def apply_svd(X_dataset):
  data = X_dataset
  data_compressed = svd_compress_image_data(data)

  images_svd = []

  for img in data_compressed:
    # transform image to array
    img = img_to_array(img)

    # append to images
    images_svd.append(img)

  images_svd = np.stack(images_svd)

  return images_svd

# %%
X_train_svd = apply_svd(X_train)

# %%
X_val_svd = apply_svd(X_val)

# %%
X_test_svd = apply_svd(X_test)

# %% [markdown]
# ## KMeans

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
#from sklearn.mixture import GaussianMixture as GMM
#from sklearn.datasets import make_moons
#from sklearn.cluster import SpectralClustering

# %%
X_flat = np.reshape(X_train_svd, (X_train_svd.shape[0], 65536))

# %%
X_flat_val = np.reshape(X_val_svd, (X_val_svd.shape[0], 65536))

# %%
kmeans10 = KMeans(n_clusters=10,
                init='k-means++',
                n_init=10,
                max_iter=300,
                tol=1e-04,
                random_state=0)
labels10 = kmeans10.fit(X_flat).predict(X_flat)

# %%
kmeans4 = KMeans(n_clusters=4,
                init='k-means++',
                n_init=10,
                max_iter=300,
                tol=1e-04,
                random_state=0)
labels4 = kmeans4.fit(X_flat).predict(X_flat)

# %%
labels10_val = kmeans10.predict(X_flat_val)

# %%
labels4_val = kmeans4.predict(X_flat_val)

# %%
label_0_x_train = X_train[labels10 == 0]
label_1_x_train = X_train[labels10 == 1]
label_2_x_train = X_train[labels10 == 2]
label_3_x_train = X_train[labels10 == 3]
label_4_x_train = X_train[labels10 == 4]
label_5_x_train = X_train[labels10 == 5]
label_6_x_train = X_train[labels10 == 6]
label_7_x_train = X_train[labels10 == 7]
label_8_x_train = X_train[labels10 == 8]
label_9_x_train = X_train[labels10 == 9]

# %%
label_40_x_train = X_train[labels4 == 0]
label_41_x_train = X_train[labels4 == 1]
label_42_x_train = X_train[labels4 == 2]
label_43_x_train = X_train[labels4 == 3]

# %%
label_0_avg = np.mean(label_0_x_train, axis = 0)
label_1_avg = np.mean(label_1_x_train, axis = 0)
label_2_avg = np.mean(label_2_x_train, axis = 0)
label_3_avg = np.mean(label_3_x_train, axis = 0)
label_4_avg = np.mean(label_4_x_train, axis = 0)
label_5_avg = np.mean(label_5_x_train, axis = 0)
label_6_avg = np.mean(label_6_x_train, axis = 0)
label_7_avg = np.mean(label_7_x_train, axis = 0)
label_8_avg = np.mean(label_8_x_train, axis = 0)
label_9_avg = np.mean(label_9_x_train, axis = 0)

# %%
label_40_avg = np.mean(label_40_x_train, axis = 0)
label_41_avg = np.mean(label_41_x_train, axis = 0)
label_42_avg = np.mean(label_42_x_train, axis = 0)
label_43_avg = np.mean(label_43_x_train, axis = 0)

# %% [markdown]
# ## Labels 10 Average Images

# %%
labels10_df = pd.DataFrame(labels10)
labels10_df.value_counts(normalize=True)
# Out:
# 9    0.216461
# 8    0.149857
# 7    0.141770
# 6    0.125595
# 2    0.108944
# 5    0.085633
# 4    0.083254
# 1    0.045671
# 3    0.030923
# 0    0.011893
# dtype: float64

# %%
print("Label 9:")
print("Number of Images: ", labels10_df.value_counts()[9])
print("Percent of Images: ", round((labels10_df.value_counts()[9] / len(labels10_df))*100,1))
array_to_img(label_9_avg)
# Out:
# Label 9:
# Number of Images:  455
# Percent of Images:  21.6
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_9_y_train = y_train_dense[labels10 == 9]
label_9_df = pd.DataFrame(label_9_y_train)
label_9_df.value_counts(sort=False)
# Out:
# 0     40
# 1    105
# 2    135
# 3    175
# dtype: int64

# %%
label_9_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 200])
# Out:
# (0.0, 200.0)

# %%
print("Label 8:")
print("Number of Images: ", labels10_df.value_counts()[8])
print("Percent of Images: ", round((labels10_df.value_counts()[8] / len(labels10_df))*100,1))
array_to_img(label_8_avg)
# Out:
# Label 8:
# Number of Images:  315
# Percent of Images:  15.0
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_8_y_train = y_train_dense[labels10 == 8]
label_8_df = pd.DataFrame(label_8_y_train)
label_8_df.value_counts(sort=False)
# Out:
# 0     56
# 1    182
# 2     37
# 3     40
# dtype: int64

# %%
label_8_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 200])
# Out:
# (0.0, 200.0)

# %%
print("Label 7:")
print("Number of Images: ", labels10_df.value_counts()[7])
print("Percent of Images: ", round((labels10_df.value_counts()[7] / len(labels10_df))*100,1))
array_to_img(label_7_avg)
# Out:
# Label 7:
# Number of Images:  298
# Percent of Images:  14.2
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_7_y_train = y_train_dense[labels10 == 7]
label_7_df = pd.DataFrame(label_7_y_train)
label_7_df.value_counts(sort=False)
# Out:
# 0     50
# 1     55
# 2     57
# 3    136
# dtype: int64

# %%
label_7_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 200])
# Out:
# (0.0, 200.0)

# %%
print("Label 6:")
print("Number of Images: ", labels10_df.value_counts()[6])
print("Percent of Images: ", round((labels10_df.value_counts()[6] / len(labels10_df))*100,1))
array_to_img(label_6_avg)
# Out:
# Label 6:
# Number of Images:  264
# Percent of Images:  12.6
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_6_y_train = y_train_dense[labels10 == 6]
label_6_df = pd.DataFrame(label_6_y_train)
label_6_df.value_counts(sort=False)
# Out:
# 0     15
# 1     92
# 2    112
# 3     45
# dtype: int64

# %%
label_6_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 200])
# Out:
# (0.0, 200.0)

# %%
print("Label 2:")
print("Number of Images: ", labels10_df.value_counts()[2])
print("Percent of Images: ", round((labels10_df.value_counts()[2] / len(labels10_df))*100,1))
array_to_img(label_2_avg)
# Out:
# Label 2:
# Number of Images:  229
# Percent of Images:  10.9
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_2_y_train = y_train_dense[labels10 == 2]
label_2_df = pd.DataFrame(label_2_y_train)
label_2_df.value_counts(sort=False)
# Out:
# 0     19
# 1     40
# 2     51
# 3    119
# dtype: int64

# %%
label_2_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 200])
# Out:
# (0.0, 200.0)

# %%
print("Label 5:")
print("Number of Images: ", labels10_df.value_counts()[5])
print("Percent of Images: ", round((labels10_df.value_counts()[5] / len(labels10_df))*100,1))
array_to_img(label_5_avg)
# Out:
# Label 5:
# Number of Images:  180
# Percent of Images:  8.6
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_5_y_train = y_train_dense[labels10 == 5]
label_5_df = pd.DataFrame(label_5_y_train)
label_5_df.value_counts(sort=False)
# Out:
# 0    116
# 1     16
# 2     44
# 3      4
# dtype: int64

# %%
label_5_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 200])
# Out:
# (0.0, 200.0)

# %%
print("Label 4:")
print("Number of Images: ", labels10_df.value_counts()[4])
print("Percent of Images: ", round((labels10_df.value_counts()[4] / len(labels10_df))*100,1))
array_to_img(label_4_avg)
# Out:
# Label 4:
# Number of Images:  175
# Percent of Images:  8.3
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_4_y_train = y_train_dense[labels10 == 4]
label_4_df = pd.DataFrame(label_4_y_train)
label_4_df.value_counts(sort=False)
# Out:
# 0    104
# 1     18
# 2     44
# 3      9
# dtype: int64

# %%
label_4_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 200])
# Out:
# (0.0, 200.0)

# %%
print("Label 1:")
print("Number of Images: ", labels10_df.value_counts()[1])
print("Percent of Images: ", round((labels10_df.value_counts()[1] / len(labels10_df))*100,1))
array_to_img(label_1_avg)
# Out:
# Label 1:
# Number of Images:  96
# Percent of Images:  4.6
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_1_y_train = y_train_dense[labels10 == 1]
label_1_df = pd.DataFrame(label_1_y_train)
label_1_df.value_counts(sort=False)
# Out:
# 0    82
# 1     2
# 2    12
# dtype: int64

# %%
label_1_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 200])
# Out:
# (0.0, 200.0)

# %%
print("Label 3:")
print("Number of Images: ", labels10_df.value_counts()[3])
print("Percent of Images: ", round((labels10_df.value_counts()[3] / len(labels10_df))*100,1))
array_to_img(label_3_avg)
# Out:
# Label 3:
# Number of Images:  65
# Percent of Images:  3.1
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_3_y_train = y_train_dense[labels10 == 3]
label_3_df = pd.DataFrame(label_3_y_train)
label_3_df.value_counts(sort=False)
# Out:
# 0    42
# 1     4
# 2    19
# dtype: int64

# %%
label_3_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 200])
# Out:
# (0.0, 200.0)

# %%
print("Label 0:")
print("Number of Images: ", labels10_df.value_counts()[0])
print("Percent of Images: ", round((labels10_df.value_counts()[0] / len(labels10_df))*100,1))
array_to_img(label_0_avg)
# Out:
# Label 0:
# Number of Images:  25
# Percent of Images:  1.2
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_0_y_train = y_train_dense[labels10 == 0]
label_0_df = pd.DataFrame(label_0_y_train)
label_0_df.value_counts(sort=False)
# Out:
# 0    18
# 2     7
# dtype: int64

# %%
label_0_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 200])
# Out:
# (0.0, 200.0)

# %% [markdown]
# ## Labels 4 Average Images

# %%
labels4_df = pd.DataFrame(labels4)
labels4_df.value_counts(normalize=True)
# Out:
# 3    0.448620
# 0    0.400571
# 1    0.117507
# 2    0.033302
# dtype: float64

# %%
print("Label 3:")
print("Number of Images: ", labels4_df.value_counts()[3])
print("Percent of Images: ", round((labels4_df.value_counts()[3] / len(labels4_df))*100,1))
array_to_img(label_43_avg)
# Out:
# Label 3:
# Number of Images:  943
# Percent of Images:  44.9
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_43_y_train = y_train_dense[labels4 == 3]
label_43_df = pd.DataFrame(label_43_y_train)
label_43_df.value_counts(sort=False)
# Out:
# 0    192
# 1    335
# 2    247
# 3    169
# dtype: int64

# %%
label_43_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 375])
# Out:
# (0.0, 375.0)

# %%
print("Label 0:")
print("Number of Images: ", labels4_df.value_counts()[0])
print("Percent of Images: ", round((labels4_df.value_counts()[0] / len(labels4_df))*100,1))
array_to_img(label_40_avg)
# Out:
# Label 0:
# Number of Images:  842
# Percent of Images:  40.1
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_40_y_train = y_train_dense[labels4 == 0]
label_40_df = pd.DataFrame(label_40_y_train)
label_40_df.value_counts(sort=False)
# Out:
# 0    133
# 1    163
# 2    189
# 3    357
# dtype: int64

# %%
label_40_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 375])
# Out:
# (0.0, 375.0)

# %%
print("Label 1:")
print("Number of Images: ", labels4_df.value_counts()[1])
print("Percent of Images: ", round((labels4_df.value_counts()[1] / len(labels4_df))*100,1))
array_to_img(label_41_avg)
# Out:
# Label 1:
# Number of Images:  247
# Percent of Images:  11.8
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_41_y_train = y_train_dense[labels4 == 1]
label_41_df = pd.DataFrame(label_41_y_train)
label_41_df.value_counts(sort=False)
# Out:
# 0    175
# 1     10
# 2     60
# 3      2
# dtype: int64

# %%
label_41_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 375])
# Out:
# (0.0, 375.0)

# %%
print("Label 2:")
print("Number of Images: ", labels4_df.value_counts()[2])
print("Percent of Images: ", round((labels4_df.value_counts()[2] / len(labels4_df))*100,1))
array_to_img(label_42_avg)
# Out:
# Label 2:
# Number of Images:  70
# Percent of Images:  3.3
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_42_y_train = y_train_dense[labels4 == 2]
label_42_df = pd.DataFrame(label_42_y_train)
label_42_df.value_counts(sort=False)
# Out:
# 0    42
# 1     6
# 2    22
# dtype: int64

# %%
label_42_df.value_counts(sort=False).plot(kind='bar')
ax = plt.gca()
ax.set_ylim([0, 375])
# Out:
# (0.0, 375.0)

# %% [markdown]
# ## Build CNN + KMeans10 Model

# %%
def build_CNN_KMeans_model():
  # Clear session and remove randomness.
  tf.keras.backend.clear_session()
  tf.random.set_seed(0)

  images = tf.keras.layers.Input(shape=(256, 256, 1), dtype=tf.float32, name='Images')
  kmeans_labels = tf.keras.layers.Input(shape=(1,), dtype=tf.float32, name='KMeans_Labels')

  features = tf.keras.layers.Add()(
      [images, kmeans_labels])

  conv_1 = tf.keras.layers.Conv2D(
    filters=32,
    kernel_size=5,
    strides=1,
    #kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01),
    padding='same',
    data_format='channels_last',
    name='conv_1',
    activation='relu'
      )(features)

  b1 = layers.BatchNormalization()(conv_1)

  pool_1 = tf.keras.layers.MaxPool2D(
    pool_size=2,
    name='pool_1')(b1)

  conv_2 = tf.keras.layers.Conv2D(
    filters=64,
    kernel_size=5,
    strides=1,
    #kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01),
    padding='same',
    name='conv_2',
    activation='relu')(pool_1)

  b2 = layers.BatchNormalization()(conv_2)

  pool_2 = tf.keras.layers.MaxPool2D(
    pool_size=2, name='pool_2')(b2)

  conv_3 = tf.keras.layers.Conv2D(
    filters=128,
    kernel_size=5,
    strides=1,
    #kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01),
    padding='same',
    name='conv_3',
    activation='relu')(pool_2)

  b3 = layers.BatchNormalization()(conv_3)

  pool_3 = tf.keras.layers.MaxPool2D(
    pool_size=2, name='pool_3')(b3)

  flat = tf.keras.layers.Flatten()(pool_3)

  dense = tf.keras.layers.Dense(
    units=1024,
    name='dense',
    activation='relu')(flat)

  drop = tf.keras.layers.Dropout(
    rate=0.5)(dense)

  preds = tf.keras.layers.Dense(
      units=4, activation='softmax', name='Predictions')(drop)

  model = tf.keras.Model(inputs=[images, kmeans_labels],
                         outputs=preds,
                         name='CNN')
  model.compile(
      optimizer=tf.keras.optimizers.Adam(),
      loss="sparse_categorical_crossentropy",
      metrics=['accuracy'])

  return model

# %%
model_cnn_kmeans10 = build_CNN_KMeans_model()

history = model_cnn_kmeans10.fit(
  x={
      'Images': X_train_svd,
      'KMeans_Labels': labels10
    },
  y=y_train_dense,
  epochs=25,
  #batch_size=16,
  validation_data=(
      {
        'Images': X_val_svd,
        'KMeans_Labels': labels10_val
      },
      y_val_dense)
)
# Out:
# Epoch 1/25
# 66/66 [==============================] - 22s 167ms/step - loss: 27.7594 - accuracy: 0.5171 - val_loss: 44.5940 - val_accuracy: 0.3486
# Epoch 2/25
# 66/66 [==============================] - 8s 122ms/step - loss: 3.5347 - accuracy: 0.5742 - val_loss: 8.8915 - val_accuracy: 0.3457
# Epoch 3/25
# 66/66 [==============================] - 8s 124ms/step - loss: 1.4051 - accuracy: 0.6323 - val_loss: 2.5537 - val_accuracy: 0.6371
# Epoch 4/25
# 66/66 [==============================] - 8s 122ms/step - loss: 1.1111 - accuracy: 0.6456 - val_loss: 2.7078 - val_accuracy: 0.7029
# Epoch 5/25
# 66/66 [==============================] - 8s 125ms/step - loss: 1.2467 - accuracy: 0.6679 - val_loss: 2.2602 - val_accuracy: 0.6914
# Epoch 6/25
# 66/66 [==============================] - 8s 122ms/step - loss: 0.9559 - accuracy: 0.6698 - val_loss: 1.5014 - val_accuracy: 0.7171
# Epoch 7/25
# ...

# %%
hist = history.history
x_arr = np.arange(len(hist['loss'])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, hist['loss'], '-o', label='Train loss')
ax.plot(x_arr, hist['val_loss'], '--<', label='Validation loss')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=25)
ax.set_ylabel('Loss', size=25)

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, hist['accuracy'], '-o', label='Train acc.')
ax.plot(x_arr, hist['val_accuracy'], '--<', label='Validation acc.')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=25)
ax.set_ylabel('Accuracy', size=25)
plt.show()

# %%
X_flat_test = np.reshape(X_test_svd, (X_test_svd.shape[0], 65536))

# %%
labels10_test = kmeans10.predict(X_flat_test)

# %%
test_results = model_cnn_kmeans10.evaluate(x={
    'Images': X_test_svd,
    'KMeans_Labels': labels10_test
    }, y=y_test_dense)
print('\nTest Acc. {:.2f}%'.format(test_results[1]*100))
# Out:
# 11/11 [==============================] - 1s 92ms/step - loss: 21.3631 - accuracy: 0.3789
#
# Test Acc. 37.89%

# %%
model_cnn_kmeans4 = build_CNN_KMeans_model()

history = model_cnn_kmeans4.fit(
  x={
      'Images': X_train_svd,
      'KMeans_Labels': labels4
    },
  y=y_train_dense,
  epochs=25,
  #batch_size=16,
  validation_data=(
      {
        'Images': X_val_svd,
        'KMeans_Labels': labels4_val
      },
      y_val_dense)
)
# Out:
# Epoch 1/25
# 66/66 [==============================] - 11s 131ms/step - loss: 30.0807 - accuracy: 0.5100 - val_loss: 203.9056 - val_accuracy: 0.2771
# Epoch 2/25
# 66/66 [==============================] - 8s 125ms/step - loss: 2.9933 - accuracy: 0.5885 - val_loss: 6.7845 - val_accuracy: 0.4829
# Epoch 3/25
# 66/66 [==============================] - 8s 123ms/step - loss: 1.2308 - accuracy: 0.5837 - val_loss: 2.1735 - val_accuracy: 0.6000
# Epoch 4/25
# 66/66 [==============================] - 8s 125ms/step - loss: 1.2179 - accuracy: 0.6218 - val_loss: 2.6245 - val_accuracy: 0.6314
# Epoch 5/25
# 66/66 [==============================] - 8s 127ms/step - loss: 1.1260 - accuracy: 0.6070 - val_loss: 5.3690 - val_accuracy: 0.6600
# Epoch 6/25
# 66/66 [==============================] - 8s 125ms/step - loss: 1.2383 - accuracy: 0.6641 - val_loss: 2.5847 - val_accuracy: 0.7000
# Epoch 7/25
# ...

# %%
hist = history.history
x_arr = np.arange(len(hist['loss'])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, hist['loss'], '-o', label='Train loss')
ax.plot(x_arr, hist['val_loss'], '--<', label='Validation loss')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=25)
ax.set_ylabel('Loss', size=25)

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, hist['accuracy'], '-o', label='Train acc.')
ax.plot(x_arr, hist['val_accuracy'], '--<', label='Validation acc.')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=25)
ax.set_ylabel('Accuracy', size=25)
plt.show()

# %%
labels4_test = kmeans4.predict(X_flat_test)

# %%
test_results = model_cnn_kmeans4.evaluate(x={
    'Images': X_test_svd,
    'KMeans_Labels': labels4_test
    }, y=y_test_dense)
print('\nTest Acc. {:.2f}%'.format(test_results[1]*100))
# Out:
# 11/11 [==============================] - 0s 33ms/step - loss: 3.0240 - accuracy: 0.7236
#
# Test Acc. 72.36%

# %% [markdown]
# ## Analyze Results

# %%
val_results = model_cnn.evaluate(X_val_svd, y_val_dense)
print('\nVal Acc. {:.2f}%'.format(val_results[1]*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-be7295a04cd1> in <cell line: 1>()
# ----> 1 val_results = model_cnn.evaluate(X_val_svd, y_val_dense)
#       2 print('\nVal Acc. {:.2f}%'.format(val_results[1]*100))
#
# NameError: name 'model_cnn' is not defined

# %%
pred_labels = model_cnn.predict(X_val_svd)

# %%
# plot test data and associated predicred
fig = plt.figure(figsize=(20, 20))

for j, example in enumerate(X_val_svd):
    ax = fig.add_subplot(8,4, min(j+1, 32))
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(array_to_img(example))
    label = str(y_val_dense[j])


    ax.text(
        0.5, -0.15,
        'Label: {:s} Pred: {:s}'.format(label, str(pred_labels[j])),
        size=8,
        color='grey',
        horizontalalignment='center',
        verticalalignment='center',
        transform=ax.transAxes)

plt.tight_layout()
plt.show()

# %%
# Create a confusion matrix as a 2D array.
confusion_matrix = tf.math.confusion_matrix(y_val_dense, pred_labels)

# Use a heatmap plot to display it.
ax = sns.heatmap(confusion_matrix, annot=True, fmt='.3g', cmap='Blues',
                 xticklabels=label_names, yticklabels=label_names, cbar=False)

# Add axis labels.
ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.show()
